# %%
import pandas as pd
dataset = pd.read_csv("insurance_pre.csv")
dataset = pd.get_dummies(dataset, drop_first=True, dtype=int)
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
#split train and test data
#from sklearn.model_selection import train_test_split
#x_train,x_test,y_train,y_test = train_test_split(independent, dependent, test_size = 0.30, random_state = 0)

# %%
#using GridSearchCrossValidation, no need to split/pre process the input and output.
#It will directly give best model with hyper tuning parameter.
#Model creation 
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion' : ('squared_error','absolute_error','friedman_mse','poisson'),
             'max_features' : ('sqrt','log2')}
regressor = GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
regressor.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ('squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'),
#                          'max_features': ('sqrt', 'log2')},
#              verbose=3)

# %%
bestParamResult = regressor.cv_results_
print("The R_score value for best parameter {}:".format(regressor.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'sqrt'}:

# %%
table = pd.DataFrame.from_dict(bestParamResult)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.538909      0.008889         0.034642        0.001350
# 1       0.532451      0.016647         0.033948        0.003246
# 2       1.606413      0.021032         0.031565        0.001524
# 3       1.620149      0.034954         0.032604        0.000705
# 4       0.522451      0.011078         0.031057        0.000432
# 5       0.526120      0.011339         0.033489        0.001151
# 6       0.586544      0.007264         0.034488        0.002803
# 7       0.567493      0.015215         0.028878        0.005441
#
#   param_criterion param_max_features  \
# 0   squared_error               sqrt
# 1   squared_error               log2
# 2  absolute_error               sqrt
# 3  absolute_error               log2
# 4    friedman_mse               sqrt
# 5    friedman_mse               log2
# 6         poisson               sqrt
# 7         poisson               log2
#
# ...

# %%
finalResult = regressor.predict([[543,12,9,0,1]])
finalResult
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([25445.6327287])
